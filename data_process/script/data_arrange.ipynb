# %%
import pandas as pd
import csv

# %%
df = pd.read_csv('../data/ped_agent.csv')

# %%
df
# Out:
#                    %time  field.header.seq   field.header.stamp  \
# 0    1654076900258511626              6968  1654076900258042480
# 1    1654076900298853116              6969  1654076900298220556
# 2    1654076900340271016              6970  1654076900338927218
# 3    1654076900382162759              6971  1654076900380439206
# 4    1654076900423599476              6972  1654076900420677124
# ..                   ...               ...                  ...
# 838  1654076933821697974              7806  1654076933778515255
# 839  1654076933869595354              7807  1654076933820466995
# 840  1654076933869708803              7808  1654076933859521437
# 841  1654076933913855908              7809  1654076933899353334
# 842  1654076933942038181              7810  1654076933940239002
#
#     field.header.frame_id  field.agent_states0.header.seq  \
# 0                    odom                               0
# 1                    odom                               0
# ...

# %%
for topic in df.columns:
    if '.force' in topic:
        del df[topic]

# %%
i=0
for topic in df.columns:
    i+=1
    print (topic)
print(i)
# Out:
# %time
# field.header.seq
# field.header.stamp
# field.header.frame_id
# field.agent_states0.header.seq
# field.agent_states0.header.stamp
# field.agent_states0.header.frame_id
# field.agent_states0.id
# field.agent_states0.type
# field.agent_states0.social_state
# field.agent_states0.pose.position.x
# field.agent_states0.pose.position.y
# field.agent_states0.pose.position.z
# field.agent_states0.pose.orientation.x
# field.agent_states0.pose.orientation.y
# field.agent_states0.pose.orientation.z
# field.agent_states0.pose.orientation.w
# field.agent_states0.twist.linear.x
# field.agent_states0.twist.linear.y
# field.agent_states0.twist.linear.z
# field.agent_states0.twist.angular.x
# field.agent_states0.twist.angular.y
# field.agent_states0.twist.angular.z
# field.agent_states1.header.seq
# field.agent_states1.header.stamp
# field.agent_states1.header.frame_id
# field.agent_states1.id
# field.agent_states1.type
# field.agent_states1.social_state
# field.agent_states1.pose.position.x
# ...
